# %%
import skimage.data
import skimage.transform

import sys

import PIL

import PIL.Image

# %%
imgID = 20309

# %%
#img = PIL.Image.open('/data/training_data/train/%s.jpg' % imgID)
img = PIL.Image.open('/data/test_data/test/%s.jpg' % imgID)

# %%
img.size
# Out:
# (1000, 651)

# %%
towidth = 100
wpercent = (towidth/float(img.size[0]))
toheight = int((float(img.size[1])*float(wpercent)))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-16752f275a0d> in <module>()
#       1 towidth = 100
# ----> 2 wpercent = (towidth/float(img.size[0]))
#       3 toheight = int((float(img.size[1])*float(wpercent)))
#
# NameError: name 'img' is not defined

# %%
toheight = 100
hpercent = (toheight/float(img.size[1]))
towidth = int((float(img.size[0])*float(hpercent)))

# %%
(towidth, toheight)
# Out:
# (153, 100)

# %%
resized = img.resize((towidth,toheight), PIL.Image.ANTIALIAS)

# %%
resized
# Out:
# <PIL.Image.Image image mode=RGB size=153x100 at 0x7F9D38646BA8>

# %%
#resized.save('/data/training_data/train/%s.jpg' % imgID)
resized.save('/data/test_data/test/%s.jpg' % imgID)
